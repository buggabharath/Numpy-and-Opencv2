# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('Data/cal.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (720, 576, 3)

# %%
# MatplotLib ---> RGB Red Green Blue
# Open Cv2 --> Blue Green Red

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('Data/cal.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (720, 576)

# %%
img_gray.max()
# Out:
# 243

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
fix_img.shape
# Out:
# (720, 576, 3)

# %%
new_img = cv2.resize(fix_img, (1080, 960))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.6  #60% of original width
h_ratio = 0.4  #40% of original height

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (288, 346, 3)

# %%
new_img2 = fix_img.copy()

# %%
plt.imshow(new_img2)

# %%
new_img3 = cv2.flip(new_img2, -1)
plt.imshow(new_img3)

# %%
cv2.imwrite('total_new.jpg', fix_img)
# Out:
# True
