# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Data/danny.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x675 at 0x1BACBC02240>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (675, 540, 3)

# %%
 plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (675, 540, 3)

# %%
# R G B

#Red color Channel
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
#Green Channel
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
#Blue Channel
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
plt.imshow(pic_red[:,:, 1])

# %%
plt.imshow(pic_red[:,:, 2])

# %%
plt.imshow(pic_red[:,:, 0])

# %%
pic_red[:,:,0] = 0

# %%
plt.imshow(pic_red)
