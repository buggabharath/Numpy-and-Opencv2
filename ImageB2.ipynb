# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Data/cal.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=576x720 at 0x28A89010EB8>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arry = np.asarray(pic)

# %%
type(pic_arry)
# Out:
# numpy.ndarray

# %%
pic_arry.shape
# Out:
# (720, 576, 3)

# %%
plt.imshow(pic_arry)

# %%
plt.imshow(pic_arry[:,:,0], cmap='gray')

# %%
plt.imshow(pic_arry[:,:,1], cmap='gray')

# %%
plt.imshow(pic_arry[:,:,2], cmap='gray')
